# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('DATA/kc_house_data.csv')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %% [markdown]
# VISUALIZATIONS

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['price'])

# %%
sns.countplot(df['bedrooms'])

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
sns.scatterplot(data=df, x ='price',y='sqft_living')

# %%
sns.boxplot(data=df, x= 'bedrooms',y= 'price')

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x='price',y='long',data=df)

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x='price',y='long',data=df)

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x='long',y='lat',data=df,hue='price')

# %%
df.sort_values('price',ascending=False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
len(df)*0.01
# Out:
# 215.97

# %%
newdf = df.sort_values('price',ascending=False).iloc[216:]

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x='long',y='lat',data=newdf,
               edgecolor=None,alpha=0.2,palette='RdYlGn',hue='price')

# %%
sns.boxplot(x='waterfront',y='price',data=df)

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df = df.drop('id',axis=1)

# %%
df['date']= pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %% [markdown]
# YEAR extraction

# %%
df['year'] = df['date'].apply(lambda date:date.year)
df['month'] = df['date'].apply(lambda date:date.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
plt.figure(figsize = (10,7))
sns.boxplot(x='month', y= 'price',data= df)

# %%
df.groupby('month').mean()['price'].plot()

# %%
df.groupby('year').mean()['price'].plot()

# %%
df = df.drop('date',axis=1)

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'year', 'month'],
#       dtype='object')

# %% [markdown]
# zipcode as categorical

# %%
df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %% [markdown]
# 70 categories so we need to map it manuallt and findin the relation between the zipcode and price

# %%
df = df.drop('zipcode',axis=1)

# %%
df['yr_renovated'].value_counts()
# Out:
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2000       35
#         ...
# 1934        1
# 1959        1
# 1951        1
# 1948        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %% [markdown]
# some have year others dont so thinkiong intitutivelys that the higher the values have a good relation with price\
#
#
# we got luck that this can be left as it is

# %%
df['sqft_basement'].value_counts()
# Out:
# 0       13110
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 792         1
# 2590        1
# 935         1
# 2390        1
# 248         1
# Name: sqft_basement, Length: 306, dtype: int64

# %% [markdown]
# # DONE VISUALIZATION AND FEATURE ENGINEERING

# %% [markdown]
# These process are done after completing one set of coding and identifyin the problem with anamolies

# %%
21597*0.01
# Out:
# 215.97

# %%
df.sort_values(by=['price'], inplace=True, ascending=False)

# %%
df= df[216:]

# %% [markdown]
# After removing anamolies

# %% [markdown]
# .

# %%
X = df.drop('price',axis = 1).values
y = df['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=101)

# %% [markdown]
# scalling of data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # NEURAL NETWORK MODEL CREATION

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense

# %%
X_train.shape
# Out:
# (14966, 19)

# %% [markdown]
# Model is the instance for the sequential network

# %%
model = Sequential()

# %% [markdown]
# Deep layers

# %%
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))

# %% [markdown]
# output layer

# %%
model.add(Dense(1))

# %%
model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x= X_train,y = y_train, validation_data=(X_test,y_test)
         , batch_size=128,epochs=400)
# Out:
# Train on 14966 samples, validate on 6415 samples
# Epoch 1/400
# 14966/14966 [==============================] - 3s 175us/sample - loss: 346874166825.2583 - val_loss: 356858793440.6335
# Epoch 2/400
# 14966/14966 [==============================] - 0s 33us/sample - loss: 346098548746.9475 - val_loss: 354126382894.8901
# Epoch 3/400
# 14966/14966 [==============================] - 1s 35us/sample - loss: 335502285627.3559 - val_loss: 329132622991.1844
# Epoch 4/400
# 14966/14966 [==============================] - 1s 35us/sample - loss: 282479019615.1747 - val_loss: 237925235333.8463
# Epoch 5/400
# 14966/14966 [==============================] - 1s 34us/sample - loss: 162334367044.4560 - val_loss: 101455802848.7931
# Epoch 6/400
# 14966/14966 [==============================] - 0s 33us/sample - loss: 68525102314.9603 - val_loss: 56840120442.5927
# Epoch 7/400
# 14966/14966 [==============================] - 1s 35us/sample - loss: 54433463491.2757 - val_loss: 54816923064.0885
# Epoch 8/400
# ...

# %% [markdown]
# MODEL EVALUATION

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score

# %%
predict = model.predict(X_test)

# %%
mean_absolute_error(y_test,predict)
# Out:
# 97869.27685600155

# %%
mean_squared_error(y_test, predict)
# Out:
# 21284793569.94142

# %%
np.sqrt(mean_squared_error(y_test, predict))
# Out:
# 145893.08952085915

# %%
df['price'].describe()
# Out:
# count    2.138100e+04
# mean     5.183675e+05
# std      2.849428e+05
# min      7.800000e+04
# 25%      3.200000e+05
# 50%      4.500000e+05
# 75%      6.350000e+05
# max      1.970000e+06
# Name: price, dtype: float64

# %%
 5.056454e+05
# Out:
# 505645.4

# %%
explained_variance_score(y_test, predict)
# Out:
# 0.7416622782131941

# %%
plt.figure(figsize=(10,7))
plt.scatter(y_test,predict)
plt.plot(y_test,y_test,'r')

# %%
plt.figure(figsize=(10,7))
plt.scatter(y_test,predict,marker='v')

# %% [markdown]
# Outliers are making the system over shoot the values

# %% [markdown]
# evaluating only one house

# %%
df.iloc[0]
# Out:
# price            1.970000e+06
# bedrooms         4.000000e+00
# bathrooms        3.500000e+00
# sqft_living      4.370000e+03
# sqft_lot         8.510000e+03
# floors           2.000000e+00
# waterfront       0.000000e+00
# view             1.000000e+00
# condition        3.000000e+00
# grade            1.000000e+01
# sqft_above       3.610000e+03
# sqft_basement    7.600000e+02
# yr_built         2.003000e+03
# yr_renovated     0.000000e+00
# lat              4.758760e+01
# long            -1.222040e+02
# sqft_living15    2.960000e+03
# sqft_lot15       1.034700e+04
# year             2.014000e+03
# month            6.000000e+00
# Name: 6329, dtype: float64

# %%
single_house = df.drop('price',axis=1).iloc[0]

# %%
single_house= scaler.transform(single_house.values.reshape(-1,19))

# %%
model.predict(single_house)
# Out:
# array([[1109068.1]], dtype=float32)

# %%
df.head()
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 6329   1970000.0         4       3.50         4370      8510     2.0
# 12271  1960000.0         5       4.50         6200     23373     3.0
# 9166   1960000.0         3       1.75         3330     12566     1.0
# 12565  1960000.0         4       4.00         4430     31353     2.0
# 1150   1960000.0         4       2.75         3120      7898     1.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 6329            0     1          3     10        3610            760
# 12271           0     1          4     11        5050           1150
# 9166            1     4          4      8        1940           1390
# 12565           0     0          3     12        4430              0
# 1150            1     4          4      8        1560           1560
#
#        yr_built  yr_renovated      lat     long  sqft_living15  sqft_lot15  \
# ...

# %% [markdown]
# still failed

# %% [markdown]
# Don't save the model

# %%
df
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 6329   1970000.0         4       3.50         4370      8510     2.0
# 12271  1960000.0         5       4.50         6200     23373     3.0
# 9166   1960000.0         3       1.75         3330     12566     1.0
# 12565  1960000.0         4       4.00         4430     31353     2.0
# 1150   1960000.0         4       2.75         3120      7898     1.0
# ...          ...       ...        ...          ...       ...     ...
# 2139     82500.0         2       1.00          520     22334     1.0
# 8267     82000.0         3       1.00          860     10426     1.0
# 16184    81000.0         2       1.00          730      9975     1.0
# 465      80000.0         1       0.75          430      5050     1.0
# 15279    78000.0         2       1.00          780     16344     1.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...
